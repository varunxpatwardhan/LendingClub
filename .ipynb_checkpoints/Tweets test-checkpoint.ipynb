# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from flatten_json import flatten

# %%
tweets_data_path=

# %%
tweets_data=[]
tweets_file=open(tweets_data_path,'r')
for line in tweets_file:
    try:
        tweet=json.loads(line)
        tweets_data.append(tweet)
    except:
        continue

# %%
    dic_flattened = (flatten(d) for d in tweets_data)
    df = pd.DataFrame(dic_flattened)
    X=df.loc[df['lang'] == 'en']
    Y=X.select(lambda col: col.startswith('entities_hashtags_'), axis=1).filter(like='text')
    Y.dropna(axis=1,how='all',inplace=True)
    result = pd.concat([Y, X['text'],X['created_at']], axis=1)
    result.dropna(axis=0,subset=['entities_hashtags_0_text'],inplace=True)
    final_local=result[result.text.str.contains("RT @") == False]

# %%
final_local
# Out:
#             entities_hashtags_0_text entities_hashtags_1_text  \
# 17                               RFP                      NaN
# 28                             MUSIC           WhatGoesAround
# 29                            Dorset              Bournemouth
# 30                             MUSIC           WhatGoesAround
# 72                           nailart                      NaN
# 156                       openfollow                      NaN
# 182                             NUFC                      NaN
# 191                IfICouldMakeItWor                      NaN
# 195                          brother                      NaN
# 235                             toys                  animals
# 293                   LiveYourDreams             MakeItHappen
# 298                           Fiverr                      NaN
# 356                         DonnyFam                      NaN
# 360                    VeranoMTV2017                      NaN
# 373                         Politics                      NaN
# 375                              EME                    Sales
# 399                          android                      app
# 504                             SEXY                 Brunette
# 548                    VeranoMTV2017                      NaN
# 598                         DonnyFam                      NaN
# 613                          hasbeen                      NaN
# 682                            quote          WednesdayWisdom
# 737                 CancilleresXVzla                Илон_Маск
# 747                             ISIS                  AlQaeda
# 887            McLisseIfWeFallInlove                      NaN
# 899                            quote                      NaN
# 971                    VeranoMTV2017                   EDTOP5
# 1091           VICTORIATHECRIMESTATE                      NaN
# 1168                      ErykahBadu                      NaN
# 1239                         กระเป๋า             แบรนด์เนมแท้
# 1347                   VeranoMTV2017                      NaN
# 1474                LizQuenJuneBlast                      NaN
# 1506                      5MinuteMan              LifeVisuals
# 1523                         dadlife                      NaN
# 1564                           dubai                  laundry
# 1576      BAMA2017DiamondEdition_EXO                      NaN
# 1779                             Now             JuelzSantana
# 1861                          beauty                   makeup
# 1913                             tbt                      NaN
# 2022                   sorrynotsorry                      NaN
# 2122  MaishaAsubuiMadarakadayEdition                      NaN
# 2142            OfficialFaydeeArmyUK             FaydeeArmyUK
# 2340                        jelieber              Justin4MMVA
# 2521                        together                  housing
# 2534                        camgirls                  webcams
# 2665                 JE203CrIn13Days                      NaN
# 2670                        giveaway                      NaN
# 2700                   CopyFollowers                      NaN
# 2786              MunnaMichaelPoster             MunnaMichael
#
#      entities_hashtags_2_text entities_hashtags_3_text  \
# 17                        NaN                      NaN
# 28                        NaN                      NaN
# 29                   Weymouth                      NaN
# 30                        NaN                      NaN
# 72                        NaN                      NaN
# 156                       NaN                      NaN
# 182                       NaN                      NaN
# 191                       NaN                      NaN
# 195                       NaN                      NaN
# 235                       NaN                      NaN
# 293           JustReminiscing                      NaN
# 298                       NaN                      NaN
# 356                       NaN                      NaN
# 360                       NaN                      NaN
# 373                       NaN                      NaN
# 375                       NaN                      NaN
# 399                       NaN                      NaN
# 504                   Student                     Asks
# 548                       NaN                      NaN
# 598                       NaN                      NaN
# 613                       NaN                      NaN
# 682                       NaN                      NaN
# 737                 caricando                      NaN
# 747                   Taliban             PrayForKabul
# 887                       NaN                      NaN
# 899                       NaN                      NaN
# 971             VeranoMTV2017                      NaN
# 1091                      NaN                      NaN
# 1168                      NaN                      NaN
# 1239               กระเป๋าสวย              กระเป๋าzara
# 1347                      NaN                      NaN
# 1474                      NaN                      NaN
# 1506                      NaN                      NaN
# 1523                      NaN                      NaN
# 1564              drycleaners           jltperformance
# 1576                      NaN                      NaN
# 1779    TunnelVisionFreestyle                Streaming
# 1861                 skincare                      NaN
# 1913                      NaN                      NaN
# 2022                      NaN                      NaN
# 2122                      NaN                      NaN
# 2142                      NaN                      NaN
# 2340                      NaN                      NaN
# 2521               housingcom                parenting
# 2534                 camshows               lotusbabes
# 2665                      NaN                      NaN
# 2670                      NaN                      NaN
# 2700                      NaN                      NaN
# 2786                      NaN                      NaN
#
#      entities_hashtags_4_text entities_hashtags_5_text  \
# 17                        NaN                      NaN
# 28                        NaN                      NaN
# 29                        NaN                      NaN
# 30                        NaN                      NaN
# 72                        NaN                      NaN
# 156                       NaN                      NaN
# 182                       NaN                      NaN
# 191                       NaN                      NaN
# 195                       NaN                      NaN
# 235                       NaN                      NaN
# 293                       NaN                      NaN
# 298                       NaN                      NaN
# 356                       NaN                      NaN
# 360                       NaN                      NaN
# 373                       NaN                      NaN
# 375                       NaN                      NaN
# 399                       NaN                      NaN
# 504                   Teacher                 Learning
# 548                       NaN                      NaN
# 598                       NaN                      NaN
# 613                       NaN                      NaN
# 682                       NaN                      NaN
# 737                       NaN                      NaN
# 747            KabulExplosion                      NaN
# 887                       NaN                      NaN
# 899                       NaN                      NaN
# 971                       NaN                      NaN
# 1091                      NaN                      NaN
# 1168                      NaN                      NaN
# 1239                      NaN                      NaN
# 1347                      NaN                      NaN
# 1474                      NaN                      NaN
# 1506                      NaN                      NaN
# 1523                      NaN                      NaN
# 1564                      NaN                      NaN
# 1576                      NaN                      NaN
# 1779                 Internet                   TuneIn
# 1861                      NaN                      NaN
# 1913                      NaN                      NaN
# 2022                      NaN                      NaN
# 2122                      NaN                      NaN
# 2142                      NaN                      NaN
# 2340                      NaN                      NaN
# 2521                      NaN                      NaN
# 2534                     nude                     sexy
# 2665                      NaN                      NaN
# 2670                      NaN                      NaN
# 2700                      NaN                      NaN
# 2786                      NaN                      NaN
#
#      entities_hashtags_6_text  \
# 17                        NaN
# 28                        NaN
# 29                        NaN
# 30                        NaN
# 72                        NaN
# 156                       NaN
# 182                       NaN
# 191                       NaN
# 195                       NaN
# 235                       NaN
# 293                       NaN
# 298                       NaN
# 356                       NaN
# 360                       NaN
# 373                       NaN
# 375                       NaN
# 399                       NaN
# 504                    Squirt
# 548                       NaN
# 598                       NaN
# 613                       NaN
# 682                       NaN
# 737                       NaN
# 747                       NaN
# 887                       NaN
# 899                       NaN
# 971                       NaN
# 1091                      NaN
# 1168                      NaN
# 1239                      NaN
# 1347                      NaN
# 1474                      NaN
# 1506                      NaN
# 1523                      NaN
# 1564                      NaN
# 1576                      NaN
# 1779                      NaN
# 1861                      NaN
# 1913                      NaN
# 2022                      NaN
# 2122                      NaN
# 2142                      NaN
# 2340                      NaN
# 2521                      NaN
# 2534                      NaN
# 2665                      NaN
# 2670                      NaN
# 2700                      NaN
# 2786                      NaN
#
#                                                    text  \
# 17    #RFP: ARCHITECTURAL ENGINEERING AND MASTER PL....
# 28    Check Out This🎧#MUSIC: What Goes Around by Pit...
# 29    #Dorset #Bournemouth, #Weymouth women &amp; wi...
# 30    Check Out This🎧#MUSIC: What Goes Around by Pit...
# 72    Cool &amp; crazy cuticle art is spring 2017's ...
# 156   I do #openfollow let's be friend guys. Help rt...
# 182   #NUFC live blog up and running today with late...
# 191   "If I Could Make It Work" by Rich Mullins http...
# 195   @realDonaldTrump What are you a wrestler?! #br...
# 235   Snowball (TM) – Our Dancing Cockatoo #toys #an...
# 293   "SPARS" Clothing.... D dream still valid bro; ...
# 298   Check it out! tagor_rukshana will create outst...
# 356   Without breyshesh #DonnyFam https://t.co/Pdc2H...
# 360                ugurcanyy_n #VeranoMTV2017 Lady Gaga
# 373   Tairod Pugh Conviction: Tairod Pugh Convicted ...
# 375   Financial Sales Controller - EMEA @Infoblox Am...
# 399   New #android #app: Task Master Pro https://t.c...
# 504   #SEXY #Brunette #Student #Asks Her #Teacher In...
# 548                   ROOTSnyc #VeranoMTV2017 Lady Gaga
# 598              blue #DonnyFam https://t.co/5dgIJLKe3l
# 613   @KenJennings Picking on some1's child regardle...
# 682   Embrace Change.Try what you've never done so y...
# 737   Last King From Allah, Naser Mohammad Al-Yamani...
# 747   #ISIS #AlQaeda #Taliban All da liars r kill in...
# 887   Push higher! We can do this!\n\n#McLisseIfWeFa...
# 899   If you want your life to be more rewarding, yo...
# 971   vBalkayaCelal #VeranoMTV2017 Lady Gaga #EDTOP5...
# 1091  How ludicrous !#VICTORIATHECRIMESTATE https://...
# 1168  @YoleeBos Makes me think of @fatbellybella #Er...
# 1239  Price : 1,100฿ Free EMS&gt;&gt; NEW ARRIVAL! Z...
# 1347                  ROOTSnyc #VeranoMTV2017 Lady Gaga
# 1474          Mumsie124 #LizQuenJuneBlast One Direction
# 1506    #5MinuteMan Video Shoot today with #LifeVisuals
# 1523  My oldest looking cute on easter. \nhttps://t....
# 1564  Good morning every one! Have a wonderful day! ...
# 1576  I want to look at only you forever~ #BAMA2017D...
# 1779  #Now Playing #JuelzSantana - #TunnelVisionFree...
# 1861  Please RT #beauty #makeup ##skincare By Terry ...
# 1913  @kylieminogue What a beautiful picture! ❤️ #tb...
# 2022  @Heyleehales Lol mine too. Oh, wait, that's yo...
# 2122  @Gov_wilsonsaisi @alexnyash88 @radiomaisha @Dj...
# 2142  A month since London this year is going to get...
